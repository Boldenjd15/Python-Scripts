# %% [markdown]
# The data for this exercise is borrowed from [here](https://www.kaggle.com/nadintamer/top-spotify-tracks-of-2018).

# %% [markdown]
# ### 1. Read data

# %%
import pandas as pd

df = pd.read_csv(r"../data/top50.csv", encoding='ISO-8859-1')

# %% [markdown]
# _`pandas.read_csv()` documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html_

# %% [markdown]
# View data.

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %% [markdown]
# Display some basic information about this data frame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
# Unnamed: 0          50 non-null int64
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# Genre               50 non-null object
# Beats.Per.Minute    50 non-null int64
# Energy              50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# Popularity          50 non-null int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# You can also use `df.dtypes` to view data types for each column.

# %% [markdown]
# View column names.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %% [markdown]
# ### Drop a column

# %%
df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
df = df.drop(df.columns[0], axis=1)

df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %% [markdown]
# ### Modify column names

# %% [markdown]
# View column names.

# %%
df.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %% [markdown]
# Convert the column-names array into a string object.

# %%
df.columns.str

# %% [markdown]
# Example: Convert all column names into uppercase.

# %%
df.columns.str.upper()
# Out:
# Index(['TRACK.NAME', 'ARTIST.NAME', 'GENRE', 'BEATS.PER.MINUTE', 'ENERGY',
#        'DANCEABILITY', 'LOUDNESS..DB..', 'LIVENESS', 'VALENCE.', 'LENGTH.',
#        'ACOUSTICNESS..', 'SPEECHINESS.', 'POPULARITY'],
#       dtype='object')

# %% [markdown]
# Remove dots from column names.

# %%
df.columns.str.replace('.', "")
# Out:
# Index(['TrackName', 'ArtistName', 'Genre', 'BeatsPerMinute', 'Energy',
#        'Danceability', 'LoudnessdB', 'Liveness', 'Valence', 'Length',
#        'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %% [markdown]
# Save the results into the data frame.

# %%
df.columns = df.columns.str.replace('.', "")

# %%
df.head()
# Out:
#                          TrackName     ArtistName           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    BeatsPerMinute  Energy  Danceability  LoudnessdB  Liveness  Valence  \
# 0             117      55            76          -6         8       75
# 1             105      81            79          -4         8       61
# 2             190      80            40          -4        16       70
# 3              93      65            64          -8         8       55
# 4             150      65            58          -4        11       18
#
#    Length  Acousticness  Speechiness  Popularity
# 0     191             4            3          79
# 1     302             8            9          92
# 2     186            12           46          85
# 3     198            12           19          86
# 4     175            45            7          94

# %% [markdown]
# ### Correlations

# %%
corr_matrix = df.corr()

corr_matrix
# Out:
#                 BeatsPerMinute    Energy  Danceability  LoudnessdB  Liveness  \
# BeatsPerMinute        1.000000  0.043756     -0.094183    0.017016 -0.167286
# Energy                0.043756  1.000000      0.018254    0.670794  0.162768
# Danceability         -0.094183  0.018254      1.000000    0.016255 -0.149636
# LoudnessdB            0.017016  0.670794      0.016255    1.000000  0.258652
# Liveness             -0.167286  0.162768     -0.149636    0.258652  1.000000
# Valence              -0.011586  0.438820      0.172829    0.237614  0.016123
# Length               -0.139288  0.224677     -0.000185    0.219219  0.131782
# Acousticness         -0.031450 -0.339892     -0.098165   -0.138300  0.021328
# Speechiness           0.557052 -0.089860     -0.103472   -0.272213 -0.125286
# Popularity            0.196097 -0.080295     -0.071413   -0.043085  0.092564
#
#                  Valence    Length  Acousticness  Speechiness  Popularity
# BeatsPerMinute -0.011586 -0.139288     -0.031450     0.557052    0.196097
# Energy          0.438820  0.224677     -0.339892    -0.089860   -0.080295
# Danceability    0.172829 -0.000185     -0.098165    -0.103472   -0.071413
# LoudnessdB      0.237614  0.219219     -0.138300    -0.272213   -0.043085
# Liveness        0.016123  0.131782      0.021328    -0.125286    0.092564
# Valence         1.000000 -0.017782     -0.052323    -0.053242   -0.317752
# Length         -0.017782  1.000000     -0.076293     0.046755   -0.087639
# Acousticness   -0.052323 -0.076293      1.000000     0.008293   -0.034684
# Speechiness    -0.053242  0.046755      0.008293     1.000000    0.238553
# Popularity     -0.317752 -0.087639     -0.034684     0.238553    1.000000

# %% [markdown]
# Plot the correlation matrix.

# %%
# set-up

import matplotlib.pyplot as plt
import seaborn as sns

# enable inline plots
plt.ion()

# %% [markdown]
# _The `ion()` function causes the output of plotting commands to be displayed inline within frontends (like the Jupyter notebook), directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document. More details here: https://ipython.readthedocs.io/en/stable/interactive/plotting.html_

# %%
# create a heat map
sns.heatmap(corr_matrix)

plt.show()
plt.close();

# %% [markdown]
# Increase the figure size.

# %%
# set figure size
plt.figure(figsize=(12, 9))

# create a heat map
sns.heatmap(corr_matrix)

plt.show()
plt.close();

# %% [markdown]
# Change the color palette.

# %%
# define a color palette
cmap = sns.diverging_palette(10, 220, n=20)

plt.figure(figsize=(12, 9))

sns.heatmap(corr_matrix, cmap=cmap)

plt.show()
plt.close();

# %% [markdown]
# _Note: Depending on the version of `matplotlib` on your computer, some of you may see truncated top and bottom rows. This is a known bug; see https://github.com/matplotlib/matplotlib/issues/14751_

# %% [markdown]
# Adjust the truncated top and bottom rows.

# %%
plt.figure(figsize=(12, 9))

ax = sns.heatmap(corr_matrix, cmap=cmap)

ax.set_ylim(len(corr_matrix), 0)

plt.show()
plt.close();

# %% [markdown]
# ### Distributions

# %% [markdown]
# View summary statistics.

# %%
df.describe()
# Out:
#        BeatsPerMinute     Energy  Danceability  LoudnessdB   Liveness  \
# count       50.000000  50.000000      50.00000   50.000000  50.000000
# mean       120.060000  64.060000      71.38000   -5.660000  14.660000
# std         30.898392  14.231913      11.92988    2.056448  11.118306
# min         85.000000  32.000000      29.00000  -11.000000   5.000000
# 25%         96.000000  55.250000      67.00000   -6.750000   8.000000
# 50%        104.500000  66.500000      73.50000   -6.000000  11.000000
# 75%        137.500000  74.750000      79.75000   -4.000000  15.750000
# max        190.000000  88.000000      90.00000   -2.000000  58.000000
#
#          Valence      Length  Acousticness  Speechiness  Popularity
# count  50.000000   50.000000     50.000000    50.000000   50.000000
# mean   54.600000  200.960000     22.160000    12.480000   87.500000
# std    22.336024   39.143879     18.995553    11.161596    4.491489
# min    10.000000  115.000000      1.000000     3.000000   70.000000
# 25%    38.250000  176.750000      8.250000     5.000000   86.000000
# 50%    55.500000  198.000000     15.000000     7.000000   88.000000
# 75%    69.500000  217.500000     33.750000    15.000000   90.750000
# max    95.000000  309.000000     75.000000    46.000000   95.000000

# %% [markdown]
# _`pandas.DataFrame.describe` documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html_

# %% [markdown]
# Transpose the summary statistics for better visibility.

# %%
df.describe().T
# Out:
#                 count    mean        std    min     25%    50%     75%    max
# BeatsPerMinute   50.0  120.06  30.898392   85.0   96.00  104.5  137.50  190.0
# Energy           50.0   64.06  14.231913   32.0   55.25   66.5   74.75   88.0
# Danceability     50.0   71.38  11.929880   29.0   67.00   73.5   79.75   90.0
# LoudnessdB       50.0   -5.66   2.056448  -11.0   -6.75   -6.0   -4.00   -2.0
# Liveness         50.0   14.66  11.118306    5.0    8.00   11.0   15.75   58.0
# Valence          50.0   54.60  22.336024   10.0   38.25   55.5   69.50   95.0
# Length           50.0  200.96  39.143879  115.0  176.75  198.0  217.50  309.0
# Acousticness     50.0   22.16  18.995553    1.0    8.25   15.0   33.75   75.0
# Speechiness      50.0   12.48  11.161596    3.0    5.00    7.0   15.00   46.0
# Popularity       50.0   87.50   4.491489   70.0   86.00   88.0   90.75   95.0

# %% [markdown]
# Export the summary statistics.

# %%
df.describe().T.to_csv(r'../output/descr_top50.csv')

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram for one variable.

# %%
df['Energy'].hist();

# %% [markdown]
# _`pandas.DataFrame.hist` documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html_

# %% [markdown]
# Plot histograms for multiple variables.

# %%
df.hist();

# %% [markdown]
# Change the bin size.

# %%
df.hist(bins=100);

# %% [markdown]
# #### Format plots.

# %% [markdown]
# Define 10 subplots and arrange them into 5 rows and 2 columns.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2)

# %% [markdown]
# View the axes component.

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733FBD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E11548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733DF79C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733D564C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E4CF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E57A08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002173465B7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021734693A88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000217346CBC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021734703F48>]],
#       dtype=object)

# %% [markdown]
# Iterate through the axes.

# %%
for ax in axes:
    print(ax)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733FBD908>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E11548>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733DF79C8>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733D564C8>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E4CF48>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x0000021733E57A08>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x000002173465B7C8>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x0000021734693A88>]
# [<matplotlib.axes._subplots.AxesSubplot object at 0x00000217346CBC88>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x0000021734703F48>]

# %% [markdown]
# Iterate thru the column names in the data frame.

# %%
for i, col in enumerate(df.columns):
    print(i, col)
# Out:
# 0 TrackName
# 1 ArtistName
# 2 Genre
# 3 BeatsPerMinute
# 4 Energy
# 5 Danceability
# 6 LoudnessdB
# 7 Liveness
# 8 Valence
# 9 Length
# 10 Acousticness
# 11 Speechiness
# 12 Popularity

# %% [markdown]
# Isolate numeric columns.

# %%
num_cols = df.columns[3:]
num_cols
# Out:
# Index(['BeatsPerMinute', 'Energy', 'Danceability', 'LoudnessdB', 'Liveness',
#        'Valence', 'Length', 'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %% [markdown]
# Another way to isolate numeric columns is by using `df.dtypes`.

# %%
df.columns[df.dtypes=='int64']
# Out:
# Index(['BeatsPerMinute', 'Energy', 'Danceability', 'LoudnessdB', 'Liveness',
#        'Valence', 'Length', 'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %% [markdown]
# Check How many numeric columns we have.

# %%
print(len(num_cols))
# Out:
# 10

# %% [markdown]
# Plot historgams for all numeric columns.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2)

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax)
    
plt.show()
plt.close();

# %% [markdown]
# Increase the subplot figure sizes.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 9))

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax)
    ax.set_xlabel(col, weight='bold', size=10)
    
plt.show()
plt.close();

# %% [markdown]
# Improve the plot layout.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 9))

fig.tight_layout()

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax)
    ax.set_xlabel(col, weight='bold', size=10)
    
plt.show()
plt.close();

# %% [markdown]
# Remove the gridlines.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 9))
fig.tight_layout()

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax, grid=False)
    ax.set_xlabel(col, weight='bold', size=10)
    
plt.show()
plt.close();

# %% [markdown]
# Use a color palette.

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# _Seabron Documentation on 'Choosing color palettes': https://seaborn.pydata.org/tutorial/color_palettes.html_

# %% [markdown]
# Apply this color palette to the histograms.

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 9))
fig.tight_layout()

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax, grid=False, color=sns.color_palette()[i])
    ax.set_xlabel(col, weight='bold', size=10)
    
plt.show()
plt.close();

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 9))
fig.tight_layout()

for i, ax in enumerate(axes.flat):
    col = num_cols[i]
    df[col].hist(bins=100, ax=ax, grid=False, color=sns.color_palette()[i])
    ax.set_xlabel(col, weight='bold', size=10)

plt.savefig(r'../output/histograms_top50.pdf')
plt.close()

# %% [markdown]
# ### Violin/Box plots

# %% [markdown]
# The default violin plot.

# %%
sns.violinplot(x='Genre', y='Energy', data=df);

# %% [markdown]
# Check the distribution of `Genre`.

# %%
df.Genre.value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# brostep             2
# dfw rap             2
# canadian pop        2
# reggaeton           2
# country rap         2
# reggaeton flow      2
# electropop          2
# panamanian pop      2
# big room            1
# trap music          1
# r&b en espanol      1
# boy band            1
# pop house           1
# australian pop      1
# escape room         1
# atl hip hop         1
# Name: Genre, dtype: int64

# %% [markdown]
# Combine similar generes to reduce cardinality.

# %%
import numpy as np

df.loc[:, 'Genre2'] = np.where(df.Genre.str.contains('pop'), 'POP',
                        np.where(df.Genre.str.contains('hip hop'), 'HIP HOP',
                                np.where(df.Genre.str.contains('rap'), 'RAP', 'OTHER')))

df.Genre2.value_counts()
# Out:
# POP        23
# OTHER      18
# RAP         5
# HIP HOP     4
# Name: Genre2, dtype: int64

# %% [markdown]
# View data to ensure the mapping was done correctly.

# %%
df[['Genre', 'Genre2']].sort_values(by='Genre2')
# Out:
#                Genre   Genre2
# 18  canadian hip hop  HIP HOP
# 27  canadian hip hop  HIP HOP
# 14  canadian hip hop  HIP HOP
# 33       atl hip hop  HIP HOP
# 30               edm    OTHER
# 23             latin    OTHER
# 19       escape room    OTHER
# 35          big room    OTHER
# 16             latin    OTHER
# 29             latin    OTHER
# 48               edm    OTHER
# 38          boy band    OTHER
# 32         reggaeton    OTHER
# 40               edm    OTHER
# 28             latin    OTHER
# 44    r&b en espanol    OTHER
# 45           brostep    OTHER
# 46             latin    OTHER
# 47           brostep    OTHER
# 1     reggaeton flow    OTHER
# 10         reggaeton    OTHER
# 22    reggaeton flow    OTHER
# 31         dance pop      POP
# 0       canadian pop      POP
# 37               pop      POP
# 39         dance pop      POP
# 41         dance pop      POP
# 42         dance pop      POP
# 43               pop      POP
# 34         dance pop      POP
# 36    panamanian pop      POP
# 24        electropop      POP
# 25      canadian pop      POP
# 2          dance pop      POP
# 3                pop      POP
# 5                pop      POP
# 7                pop      POP
# 26    australian pop      POP
# 11         dance pop      POP
# 9         electropop      POP
# 13    panamanian pop      POP
# 15         dance pop      POP
# 20         pop house      POP
# 12               pop      POP
# 49               pop      POP
# 8        country rap      RAP
# 6         trap music      RAP
# 17           dfw rap      RAP
# 4            dfw rap      RAP
# 21       country rap      RAP

# %% [markdown]
# Plot the new genere column created above.

# %%
sns.violinplot(x='Genre2', y='Energy', data=df)

plt.show()
plt.close();

# %% [markdown]
# Increase the figure size.

# %%
plt.figure(figsize=[12, 9])

sns.violinplot(x='Genre2', y='Energy', data=df)

plt.show()
plt.close();

# %% [markdown]
# Box plot.

# %%
plt.figure(figsize=[12, 9])

sns.boxplot(x='Genre2', y='Energy', data=df)

plt.show()
plt.close();

# %% [markdown]
# Add axes labels.

# %%
plt.figure(figsize=[12, 9])

sns.violinplot(x='Genre2', y='Energy', data=df)

plt.xlabel('Genre', fontsize=14, weight='bold')
plt.ylabel('Energy', fontsize=14, weight='bold')

plt.show()
plt.close();

# %% [markdown]
# Change plot layout to add gridlines.

# %%
plt.figure(figsize=[12, 9])
sns.set_style('darkgrid')

sns.violinplot(x='Genre2', y='Energy', data=df)

plt.xlabel('Genre', fontsize=14, weight='bold')
plt.ylabel('Energy', fontsize=14, weight='bold')

plt.show()
plt.close();

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# Plot loudness versus energy.

# %%
plt.figure(figsize=[12, 9])

ax = sns.scatterplot(x='LoudnessdB', y='Energy', data=df, color='tomato')

plt.xlabel('Loundness', fontsize=14, weight='bold')
plt.ylabel('Energy', fontsize=14, weight='bold')

plt.show()
plt.close();

# %% [markdown]
# Increase the size of each dot.

# %%
plt.figure(figsize=[12, 9])

ax = sns.scatterplot(x='LoudnessdB', y='Energy', data=df, color='tomato', s=100)

plt.xlabel('Loundness', fontsize=14, weight='bold')
plt.ylabel('Energy', fontsize=14, weight='bold')

plt.show()
plt.close();

# %% [markdown]
# Label data points based on genre.

# %%
plt.figure(figsize=[12, 9])

ax = sns.scatterplot(x='LoudnessdB', y='Energy', data=df, color='tomato', s=100, hue='Genre2')

plt.xlabel('Loundness', fontsize=14, weight='bold')
plt.ylabel('Energy', fontsize=14, weight='bold')
plt.legend(loc='lower right', fontsize=12);

# %% [markdown]
# ### Data Aggregation

# %% [markdown]
# How many total artists are there in this dataset?

# %%
df.ArtistName.nunique()
# Out:
# 38

# %% [markdown]
# Frequency of occurence for each artist.

# %%
df.ArtistName.value_counts()
# Out:
# Ed Sheeran          4
# Sech                2
# Marshmello          2
# Billie Eilish       2
# Ariana Grande       2
# Shawn Mendes        2
# Post Malone         2
# Lil Nas X           2
# J Balvin            2
# The Chainsmokers    2
# Kygo                1
# Taylor Swift        1
# Lauv                1
# Khalid              1
# Jonas Brothers      1
# Anuel AA            1
# Maluma              1
# Lunay               1
# Y2K                 1
# Lewis Capaldi       1
# Martin Garrix       1
# Chris Brown         1
# Lil Tecca           1
# Bad Bunny           1
# Tones and I         1
# Jhay Cortez         1
# Lizzo               1
# Drake               1
# Daddy Yankee        1
# Sam Smith           1
# Katy Perry          1
# MEDUZA              1
# DJ Snake            1
# Ali Gatie           1
# ROSALÍA             1
# Lady Gaga           1
# Nicky Jam           1
# Young Thug          1
# Name: ArtistName, dtype: int64

# %% [markdown]
# Let's analyze (the average) popularity by genere.

# %%
df.groupby('Genre2').size()
# Out:
# Genre2
# HIP HOP     4
# OTHER      18
# POP        23
# RAP         5
# dtype: int64

# %% [markdown]
# You can also calculate the % distribution by dividing each count by the total number of records in the data frame.

# %%
df.groupby('Genre2').size() / len(df)
# Out:
# Genre2
# HIP HOP    0.08
# OTHER      0.36
# POP        0.46
# RAP        0.10
# dtype: float64

# %% [markdown]
# Use `pandas` `groupby()` function to create an object.

# %%
df.groupby('Genre2')

# %% [markdown]
# View the size of each category of `Genre2`.

# %%
df.groupby('Genre2').size()
# Out:
# Genre2
# HIP HOP     4
# OTHER      18
# POP        23
# RAP         5
# dtype: int64

# %% [markdown]
# Create a series by adding an attribute (column).

# %%
df.groupby('Genre2')['Popularity']

# %% [markdown]
# Now you can run functions, such as `mean()`, `max()` etc, on the series.

# %%
df.groupby('Genre2')['Popularity'].mean()
# Out:
# Genre2
# HIP HOP    89.500000
# OTHER      88.333333
# POP        85.739130
# RAP        91.000000
# Name: Popularity, dtype: float64

# %% [markdown]
# Save the results.

# %%
genre_size = df.groupby('Genre2').size()

genre_popularity = df.groupby('Genre2')['Popularity'].mean()

# %% [markdown]
# Create a two-axis plot to view the genre size and average popularity.

# %%
sns.set(style = 'dark')
f, ax = plt.subplots(figsize = (12, 9))

ax2 = ax.twinx()

ax.bar(genre_size.index, genre_size, color='teal', alpha=0.5)

ax2.plot(genre_popularity.index, genre_popularity, color='orangered', lw=3)

ax.set_xlabel('Genre', fontsize=14, weight='bold')
ax.set_ylabel('Count', fontsize=14, weight='bold', color='teal')
ax2.set_ylabel('Average Populatiry', fontsize = 14, color='orangered', weight='bold')

plt.show()
plt.close();

# %% [markdown]
# Sort values from larger to smaller genre.

# %%
genre_size.sort_values(ascending=False)
# Out:
# Genre2
# POP        23
# OTHER      18
# RAP         5
# HIP HOP     4
# dtype: int64

# %%
genre_size = genre_size.sort_values(ascending=False)
genre_popularity = genre_popularity.sort_values(ascending=False)

# %% [markdown]
# ### Join (combine) data

# %%
print(type(genre_size), type(genre_popularity))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %% [markdown]
# Before we can join these two `pd.Series`, we must conver one of them into `pd.DataFrame` objects.

# %%
genre_size.to_frame()
# Out:
#           0
# Genre2
# POP      23
# OTHER    18
# RAP       5
# HIP HOP   4

# %%
genre_size.to_frame().join(genre_popularity)
# Out:
#           0  Popularity
# Genre2
# POP      23   85.739130
# OTHER    18   88.333333
# RAP       5   91.000000
# HIP HOP   4   89.500000

# %% [markdown]
# See: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html

# %% [markdown]
# Reset (flatten) the multi-level column names.

# %%
genre_size.to_frame().join(genre_popularity).reset_index()
# Out:
#     Genre2   0  Popularity
# 0      POP  23   85.739130
# 1    OTHER  18   88.333333
# 2      RAP   5   91.000000
# 3  HIP HOP   4   89.500000

# %% [markdown]
# Let's save the results into a data frame.

# %%
genre_df = genre_size.to_frame().join(genre_popularity).reset_index()

genre_df.columns
# Out:
# Index(['Genre2', 0, 'Popularity'], dtype='object')

# %% [markdown]
# Rename a column in this data frame.

# %%
genre_df.rename(columns={0: 'Count'})
# Out:
#     Genre2  Count  Popularity
# 0      POP     23   85.739130
# 1    OTHER     18   88.333333
# 2      RAP      5   91.000000
# 3  HIP HOP      4   89.500000

# %%
genre_df = genre_df.rename(columns={0: 'Count'})

# %% [markdown]
# Plot the results with genre sorted from large to small.

# %%
sns.set(style = 'dark')
f, ax = plt.subplots(figsize = (12, 9))

ax2 = ax.twinx()

ax.bar(genre_df['Genre2'], genre_df['Count'], color='teal', alpha=0.3)

ax2.plot(genre_df['Genre2'], genre_df['Popularity'], color='orangered', marker='o', markersize=10)

ax.set_xlabel('Genre', fontsize=14, weight='bold')
ax.set_ylabel('Count', fontsize=14, weight='bold', color='teal')
ax2.set_ylabel('Average Populatiry', fontsize = 14, color='orangered', weight='bold')

plt.show()
plt.close();

# %% [markdown]
# ### Plotting pairwise data relationships using seaborn

# %%
g = sns.PairGrid(df)

g.map(plt.scatter);
